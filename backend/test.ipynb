# %%
import pandas as pd

# %%
pd.set_option('display.max_columns', 50)

# %%
new_data = pd.read_parquet('data/Predictions.parquet')
old_data = pd.read_csv('data/Pred.csv', index_col=0)

# %%
old_data.query('STUDENT_ID == 100059153')
# Out:
#    SCHOOL_YEAR  DISTRICT_CODE DISTRICT_NAME  LOCATION_ID    SCHOOL_NAME  \
# 0         2019             71     SANTA FE           165  SANTA FE HIGH
# 1         2020             71     SANTA FE           165  SANTA FE HIGH
# 2         2021             71     SANTA FE           165  SANTA FE HIGH
# 3         2022             71     SANTA FE           165  SANTA FE HIGH
# 4         2023             71     SANTA FE           165  SANTA FE HIGH
# 5         2024             71     SANTA FE           165  SANTA FE HIGH
#
#    STUDENT_ID  Total_Days_Unexcused_Absent  Total_Days_Enrolled  \
# 0   100059153                          0.0                190.0
# 1   100059153                          0.0                126.0
# 2   100059153                          0.0                168.0
# 3   100059153                          1.0                194.0
# 4   100059153                          1.5                171.0
# 5   100059153                          4.0                174.0
#
# ...

# %%
new_data.query('STUDENT_ID == 100059153')
# Out:
#    Total_Days_Present  Total_Days_Enrolled  Total_Days_Unexcused_Absent  \
# 0               189.0                190.0                          0.0
# 1               123.0                126.0                          0.0
# 2               166.0                168.0                          0.0
# 3               185.6                194.0                          1.0
# 4               159.3                171.0                          1.5
# 5               166.0                174.0                          4.0
# 6                 NaN                  NaN                          NaN
#
#    SCHOOL_YEAR  DISTRICT_CODE DISTRICT_NAME  LOCATION_ID  \
# 0         2019           71.0      SANTA FE        146.0
# 1         2020           71.0      SANTA FE        146.0
# 2         2021           71.0      SANTA FE        146.0
# 3         2022           71.0      SANTA FE        189.0
# 4         2023           71.0      SANTA FE        189.0
# ...
